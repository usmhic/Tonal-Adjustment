# %% [markdown]
# # Image Enhancing

# %%
# This will import Image and ImageEnhance modules
import matplotlib.pyplot as plt
from PIL import Image, ImageEnhance
  
# Opening Image
im = Image.open('../assets/image-samples/img3.jpg')
  
# Creating object of Color class
im3 = ImageEnhance.Color(im)
  
# showing resultant image
img = im3.enhance(2.0)

plt.subplot(221),plt.imshow(img)
plt.subplot(222),plt.imshow((im))
# Out:
# (<AxesSubplot:>, <matplotlib.image.AxesImage at 0x1ceefacfaf0>)
